# %%
# %matplotlib inline

import gym
import itertools
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing

if "../" not in sys.path:
  sys.path.append("../") 

from lib import plotting
from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler

matplotlib.style.use('ggplot')

# %%
env = gym.envs.make("MountainCar-v0")

# %%
# Feature Preprocessing: Normalize to zero mean and unit variance
# We use a few samples from the observation space to do this
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(observation_examples)

# Used to convert a state to a featurizes represenation.
# We use RBF kernels with different variances to cover different parts of the space
featurizer = sklearn.pipeline.FeatureUnion([
        ("rbf1", RBFSampler(gamma=5.0, n_components=100)),
        ("rbf2", RBFSampler(gamma=2.0, n_components=100)),
        ("rbf3", RBFSampler(gamma=1.0, n_components=100)),
        ("rbf4", RBFSampler(gamma=0.5, n_components=100))
        ])
featurizer.fit(scaler.transform(observation_examples))
# Out:
# FeatureUnion(n_jobs=None,
#              transformer_list=[('rbf1',
#                                 RBFSampler(gamma=5.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf2',
#                                 RBFSampler(gamma=2.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf3',
#                                 RBFSampler(gamma=1.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf4',
#                                 RBFSampler(gamma=0.5, n_components=100,
#                                            random_state=None))],
#              transformer_weights=None, verbose=False)

# %%
class Estimator():
    """
    Value Function approximator. 
    """
    
    def __init__(self):
        # We create a separate model for each action in the environment's
        # action space. Alternatively we could somehow encode the action
        # into the features, but this way it's easier to code up.
        self.models = []
        for _ in range(env.action_space.n):
            model = SGDRegressor(learning_rate="constant")
            # We need to call partial_fit once to initialize the model
            # or we get a NotFittedError when trying to make a prediction
            # This is quite hacky.
            model.partial_fit([self.featurize_state(env.reset())], [0])
            self.models.append(model)
    
    def featurize_state(self, state):
        """
        Returns the featurized representation for a state.
        """
        scaled = scaler.transform([state])
        featurized = featurizer.transform(scaled)
        return featurized[0]
    
    def predict(self, s, a=None):
        """
        Makes value function predictions.
        
        Args:
            s: state to make a prediction for
            a: (Optional) action to make a prediction for
            
        Returns
            If an action a is given this returns a single number as the prediction.
            If no action is given this returns a vector or predictions for all actions
            in the environment where pred[i] is the prediction for action i.
            
        """
        features = self.featurize_state(s)
        if not a:
            return np.array([m.predict([features])[0] for m in self.models])
        else:
            return self.models[a].predict([features])[0]
    
    def update(self, s, a, y):
        """
        Updates the estimator parameters for a given state and action towards
        the target y.
        """
        print(s, 'current state')
        print(a, 'action')
        print(y, 'target')
        features = self.featurize_state(s)
        self.models[a].partial_fit([features], [y])

# %%
def make_epsilon_greedy_policy(estimator, epsilon, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function approximator and epsilon.
    
    Args:
        estimator: An estimator that returns q values for a given state
        epsilon: The probability to select a random action . float between 0 and 1.
        nA: Number of actions in the environment.
    
    Returns:
        A function that takes the observation as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    
    """
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        q_values = estimator.predict(observation)
        best_action = np.argmax(q_values)
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def q_learning(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.1, epsilon_decay=1.0):
    """
    Q-Learning algorithm for fff-policy TD control using Function Approximation.
    Finds the optimal greedy policy while following an epsilon-greedy policy.
    
    Args:
        env: OpenAI environment.
        estimator: Action-Value function estimator
        num_episodes: Number of episodes to run for.
        discount_factor: Gamma discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
        epsilon_decay: Each episode, epsilon is decayed by this factor
    
    Returns:
        An EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """

    # Keeps track of useful statistics
    stats = plotting.EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))    
    
    for i_episode in range(num_episodes):
        
        # The policy we're following
        policy = make_epsilon_greedy_policy(
            estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
        
        # Print out which episode we're on, useful for debugging.
        # Also print reward for last episode
        last_reward = stats.episode_rewards[i_episode - 1]
        sys.stdout.flush()
        
        # Reset the environment and pick the first action
        state = env.reset()
        
        # Only used for SARSA, not Q-Learning
        next_action = None
        
        # One step in the environment
        for t in itertools.count():
                        
            # Choose an action to take
            # If we're using SARSA we already decided in the previous step
            if next_action is None:
                action_probs = policy(state)
                action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
            else:
                action = next_action
            
            # Take a step
            next_state, reward, done, _ = env.step(action)
    
            # Update statistics
            stats.episode_rewards[i_episode] += reward
            stats.episode_lengths[i_episode] = t
            
            # TD Update
            q_values_next = estimator.predict(next_state)
            
            # Use this code for Q-Learning
            # Q-Value TD Target
            td_target = reward + discount_factor * np.max(q_values_next)
            
            # Use this code for SARSA TD Target for on policy-training:
            # next_action_probs = policy(next_state)
            # next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)             
            # td_target = reward + discount_factor * q_values_next[next_action]
            
            # Update the function approximator using our target
            estimator.update(state, action, td_target)
            
            print("\rStep {} @ Episode {}/{} ({})".format(t, i_episode + 1, num_episodes, last_reward), end="")
                
            if done:
                break
                
            state = next_state
    
    return stats

# %%
estimator = Estimator()

# %%
# Note: For the Mountain Car we don't actually need an epsilon > 0.0
# because our initial estimate for all states is too "optimistic" which leads
# to the exploration of all states.
stats = q_learning(env, estimator, 1, epsilon=0.0)
# Out:
# [-0.51207213  0.        ] current state
# 0 action
# -1.0 target
# Step 0 @ Episode 1/1 (0.0)[-0.51315856 -0.00108643] current state
# 1 action
# -1.0 target
# Step 1 @ Episode 1/1 (0.0)[-0.51432328 -0.00116472] current state
# 2 action
# -1.0 target
# Step 2 @ Episode 1/1 (0.0)[-5.14557561e-01 -2.34278664e-04] current state
# 2 action
# -1.046483168287532 target
# Step 3 @ Episode 1/1 (0.0)[-0.51385964  0.00069792] current state
# 1 action
# -1.0465077953385633 target
# Step 4 @ Episode 1/1 (0.0)[-0.51323475  0.00062489] current state
# 0 action
# -1.0466484245682826 target
# Step 5 @ Episode 1/1 (0.0)[-5.13687583e-01 -4.52830233e-04] current state
# 1 action
# -1.0932119328065597 target
# Step 6 @ Episode 1/1 (0.0)[-0.51421474 -0.00052715] current state
# 2 action
# -1.0931873430229744 target
# Step 7 @ Episode 1/1 (0.0)[-5.13812260e-01  4.02475775e-04] current state
# 0 action
# -1.0932179121145984 target
# Step 8 @ Episode 1/1 (0.0)[-0.51448317 -0.00067091] current state
# 0 action
# -1.1391890936112636 target
# Step 9 @ Episode 1/1 (0.0)[-0.51622244 -0.00173927] current state
# 1 action
# -1.1393790507537076 target
# Step 10 @ Episode 1/1 (0.0)[-0.51801703 -0.00179459] current state
# 2 action
# -1.1398599698480758 target
# Step 11 @ Episode 1/1 (0.0)[-0.51885348 -0.00083645] current state
# 1 action
# -1.1863270884653883 target
# Step 12 @ Episode 1/1 (0.0)[-0.51972552 -0.00087204] current state
# 0 action
# -1.1855426587295992 target
# Step 13 @ Episode 1/1 (0.0)[-0.52162661 -0.00190109] current state
# 2 action
# -1.1864217262396057 target
# Step 14 @ Episode 1/1 (0.0)[-0.52254249 -0.00091588] current state
# 0 action
# -1.2320243600039293 target
# Step 15 @ Episode 1/1 (0.0)[-0.52446629 -0.0019238 ] current state
# 1 action
# -1.232386330988984 target
# Step 16 @ Episode 1/1 (0.0)[-0.52638358 -0.00191729] current state
# 2 action
# -1.2329766627957948 target
# Step 17 @ Episode 1/1 (0.0)[-0.52727999 -0.00089641] current state
# 0 action
# -1.2785641000820742 target
# Step 18 @ Episode 1/1 (0.0)[-0.52914879 -0.0018688 ] current state
# 1 action
# -1.2790010579513393 target
# Step 19 @ Episode 1/1 (0.0)[-0.53097597 -0.00182718] current state
# 2 action
# -1.2795092134564612 target
# Step 20 @ Episode 1/1 (0.0)[-0.53174782 -0.00077185] current state
# 1 action
# -1.3260311877352025 target
# Step 21 @ Episode 1/1 (0.0)[-0.53245856 -0.00071074] current state
# 0 action
# -1.3252835630369357 target
# Step 22 @ Episode 1/1 (0.0)[-0.53410286 -0.0016443 ] current state
# 2 action
# -1.326027707380978 target
# Step 23 @ Episode 1/1 (0.0)[-0.53466839 -0.00056553] current state
# 1 action
# -1.3726528600060153 target
# Step 24 @ Episode 1/1 (0.0)[-5.35150919e-01 -4.82525560e-04] current state
# 2 action
# -1.3715914375242326 target
# Step 25 @ Episode 1/1 (0.0)[-0.53454682  0.0006041 ] current state
# 0 action
# -1.3728345038608714 target
# Step 26 @ Episode 1/1 (0.0)[-5.34860627e-01 -3.13806250e-04] current state
# 2 action
# -1.418029255223508 target
# Step 27 @ Episode 1/1 (0.0)[-0.53408999  0.00077064] current state
# 1 action
# -1.4183889436397197 target
# Step 28 @ Episode 1/1 (0.0)[-0.53324067  0.00084931] current state
# 0 action
# -1.4197019868469465 target
# Step 29 @ Episode 1/1 (0.0)[-5.33319056e-01 -7.83832024e-05] current state
# 2 action
# -1.4643327806099395 target
# Step 30 @ Episode 1/1 (0.0)[-0.53232455  0.00099451] current state
# 1 action
# -1.464946182493729 target
# Step 31 @ Episode 1/1 (0.0)[-0.5312646   0.00105994] current state
# 0 action
# -1.4665534943056109 target
# Step 32 @ Episode 1/1 (0.0)[-5.31147170e-01  1.17433022e-04] current state
# 2 action
# -1.5106357284461573 target
# Step 33 @ Episode 1/1 (0.0)[-0.52997313  0.00117404] current state
# 1 action
# -1.5115282369032488 target
# Step 34 @ Episode 1/1 (0.0)[-0.52875128  0.00122185] current state
# 0 action
# -1.5133669772686726 target
# Step 35 @ Episode 1/1 (0.0)[-5.28490795e-01  2.60488145e-04] current state
# 2 action
# -1.5569705503424882 target
# Step 36 @ Episode 1/1 (0.0)[-0.52719362  0.00129718] current state
# 1 action
# -1.5581464943481231 target
# Step 37 @ Episode 1/1 (0.0)[-0.52586948  0.00132414] current state
# 0 action
# -1.5601202252815345 target
# Step 38 @ Episode 1/1 (0.0)[-5.25528312e-01  3.41167920e-04] current state
# 2 action
# -1.6033693387833778 target
# Step 39 @ Episode 1/1 (0.0)[-0.52417267  0.00135564] current state
# 1 action
# -1.6048080712683757 target
# Step 40 @ Episode 1/1 (0.0)[-0.52281273  0.00135994] current state
# 0 action
# -1.6067897830594915 target
# Step 41 @ Episode 1/1 (0.0)[-5.22458681e-01  3.54048249e-04] current state
# 2 action
# -1.649857633610808 target
# Step 42 @ Episode 1/1 (0.0)[-0.52111318  0.0013455 ] current state
# 1 action
# -1.651512433085404 target
# Step 43 @ Episode 1/1 (0.0)[-0.51978633  0.00132686] current state
# 0 action
# -1.6533507331320905 target
# Step 44 @ Episode 1/1 (0.0)[-5.19488065e-01  2.98263052e-04] current state
# 2 action
# -1.696449548425309 target
# Step 45 @ Episode 1/1 (0.0)[-0.51822063  0.00126743] current state
# 1 action
# -1.6982497353080461 target
# Step 46 @ Episode 1/1 (0.0)[-0.51699353  0.0012271 ] current state
# 0 action
# -1.6997781731359771 target
# Step 47 @ Episode 1/1 (0.0)[-5.16815969e-01  1.77563082e-04] current state
# 2 action
# -1.7431454122463719 target
# Step 48 @ Episode 1/1 (0.0)[-0.51568927  0.0011267 ] current state
# 1 action
# -1.745001659548502 target
# Step 49 @ Episode 1/1 (0.0)[-0.51462189  0.00106738] current state
# 0 action
# -1.7460507484960155 target
# Step 50 @ Episode 1/1 (0.0)[-5.14621832e-01  6.13638838e-08] current state
# 2 action
# -1.789932514963327 target
# Step 51 @ Episode 1/1 (0.0)[-0.51368909  0.00093274] current state
# 1 action
# -1.7917448937140397 target
# Step 52 @ Episode 1/1 (0.0)[-0.51283066  0.00085843] current state
# 0 action
# -1.7921559348320921 target
# Step 53 @ Episode 1/1 (0.0)[-5.13052975e-01 -2.22316100e-04] current state
# 2 action
# -1.8367887413267714 target
# Step 54 @ Episode 1/1 (0.0)[-0.51235437  0.0006986 ] current state
# 1 action
# -1.8384566555214763 target
# Step 55 @ Episode 1/1 (0.0)[-0.51174008  0.00061429] current state
# 0 action
# -1.8380960648984876 target
# Step 56 @ Episode 1/1 (0.0)[-5.12214720e-01 -4.74634868e-04] current state
# 2 action
# -1.883688083809049 target
# Step 57 @ Episode 1/1 (0.0)[-5.11774718e-01  4.40001311e-04] current state
# 1 action
# -1.8851209792197268 target
# Step 58 @ Episode 1/1 (0.0)[-5.11423379e-01  3.51339478e-04] current state
# 0 action
# -1.8838935666810408 target
# Step 59 @ Episode 1/1 (0.0)[-0.51216333 -0.00073996] current state
# 1 action
# -1.9302302155382052 target
# Step 60 @ Episode 1/1 (0.0)[-0.51298904 -0.0008257 ] current state
# 0 action
# -1.925654956211606 target
# Step 61 @ Episode 1/1 (0.0)[-0.5148943  -0.00190526] current state
# 2 action
# -1.9307468025358832 target
# Step 62 @ Episode 1/1 (0.0)[-0.51586484 -0.00097054] current state
# 0 action
# -1.9715992626865444 target
# Step 63 @ Episode 1/1 (0.0)[-0.51789338 -0.00202854] current state
# 1 action
# -1.9726072638115033 target
# Step 64 @ Episode 1/1 (0.0)[-0.51996471 -0.00207133] current state
# 2 action
# -1.977808403918504 target
# Step 65 @ Episode 1/1 (0.0)[-0.52106329 -0.00109858] current state
# 0 action
# -2.0177567067201325 target
# Step 66 @ Episode 1/1 (0.0)[-0.52318089 -0.0021176 ] current state
# 1 action
# -2.0192536741165608 target
# Step 67 @ Episode 1/1 (0.0)[-0.52530163 -0.00212073] current state
# 2 action
# -2.0248142107137825 target
# Step 68 @ Episode 1/1 (0.0)[-0.52640959 -0.00110796] current state
# 0 action
# -2.0643699273697256 target
# Step 69 @ Episode 1/1 (0.0)[-0.52849647 -0.00208688] current state
# 1 action
# -2.0662796900364917 target
# Step 70 @ Episode 1/1 (0.0)[-0.53054662 -0.00205015] current state
# 2 action
# -2.0717049261193297 target
# Step 71 @ Episode 1/1 (0.0)[-0.53154466 -0.00099804] current state
# 0 action
# -2.1114424226352595 target
# Step 72 @ Episode 1/1 (0.0)[-0.53348312 -0.00193846] current state
# 1 action
# -2.1136264151901156 target
# Step 73 @ Episode 1/1 (0.0)[-0.53534745 -0.00186433] current state
# 2 action
# -2.118387543338723 target
# Step 74 @ Episode 1/1 (0.0)[-0.53612369 -0.00077624] current state
# 0 action
# -2.158905344304215 target
# Step 75 @ Episode 1/1 (0.0)[-0.53780601 -0.00168232] current state
# 1 action
# -2.1611753330888375 target
# Step 76 @ Episode 1/1 (0.0)[-0.53938181 -0.0015758 ] current state
# 2 action
# -2.164751440935839 target
# Step 77 @ Episode 1/1 (0.0)[-5.39839285e-01 -4.57472002e-04] current state
# 0 action
# -2.2066331217792166 target
# Step 78 @ Episode 1/1 (0.0)[-0.541175   -0.00133572] current state
# 1 action
# -2.20877217486274 target
# Step 79 @ Episode 1/1 (0.0)[-0.54237896 -0.00120396] current state
# 2 action
# -2.2106957919256596 target
# Step 80 @ Episode 1/1 (0.0)[-5.42442136e-01 -6.31788817e-05] current state
# 0 action
# -2.25447188532307 target
# Step 81 @ Episode 1/1 (0.0)[-0.54336407 -0.00092193] current state
# 1 action
# -2.2562599694644456 target
# Step 82 @ Episode 1/1 (0.0)[-0.54413784 -0.00077378] current state
# 2 action
# -2.2561602433526726 target
# Step 83 @ Episode 1/1 (0.0)[-5.43757672e-01  3.80169422e-04] current state
# 2 action
# -2.2977179669286496 target
# Step 84 @ Episode 1/1 (0.0)[-0.5422264   0.00153127] current state
# 1 action
# -2.299547077320268 target
# Step 85 @ Episode 1/1 (0.0)[-0.5405555  0.0016709] current state
# 0 action
# -2.3036850103746564 target
# Step 86 @ Episode 1/1 (0.0)[-0.53975748  0.00079802] current state
# 2 action
# -2.3422546360750176 target
# Step 87 @ Episode 1/1 (0.0)[-0.53783831  0.00191917] current state
# 1 action
# -2.3451534141245345 target
# Step 88 @ Episode 1/1 (0.0)[-0.53581238  0.00202593] current state
# 0 action
# -2.35084026594068 target
# Step 89 @ Episode 1/1 (0.0)[-0.53469487  0.00111751] current state
# 2 action
# -2.386930101147697 target
# Step 90 @ Episode 1/1 (0.0)[-0.53249415  0.00220072] current state
# 1 action
# -2.3908830907295178 target
# Step 91 @ Episode 1/1 (0.0)[-0.53022672  0.00226743] current state
# 0 action
# -2.3977244942876847 target
# Step 92 @ Episode 1/1 (0.0)[-0.52890959  0.00131713] current state
# 2 action
# -2.43195727398908 target
# Step 93 @ Episode 1/1 (0.0)[-0.52655263  0.00235696] current state
# 1 action
# -2.436852268267519 target
# Step 94 @ Episode 1/1 (0.0)[-0.52417352  0.00237911] current state
# 0 action
# -2.4443277867432496 target
# Step 95 @ Episode 1/1 (0.0)[-0.52279009  0.00138343] current state
# 2 action
# -2.4774923911420346 target
# Step 96 @ Episode 1/1 (0.0)[-0.52041273  0.00237736] current state
# 1 action
# -2.483118575519532 target
# Step 97 @ Episode 1/1 (0.0)[-0.51805927  0.00235346] current state
# 0 action
# -2.490606744574964 target
# Step 98 @ Episode 1/1 (0.0)[-0.51674735  0.00131192] current state
# 2 action
# -2.523605106456805 target
# Step 99 @ Episode 1/1 (0.0)[-0.51448681  0.00226054] current state
# 1 action
# -2.5296638105999696 target
# Step 100 @ Episode 1/1 (0.0)[-0.5122946   0.00219221] current state
# 0 action
# -2.5364807157748466 target
# Step 101 @ Episode 1/1 (0.0)[-0.51118716  0.00110744] current state
# 2 action
# -2.57026821106969 target
# Step 102 @ Episode 1/1 (0.0)[-0.50917278  0.00201438] current state
# 1 action
# -2.5763963181910756 target
# Step 103 @ Episode 1/1 (0.0)[-0.50726657  0.00190622] current state
# 0 action
# -2.5818462339471795 target
# Step 104 @ Episode 1/1 (0.0)[-0.50648279  0.00078377] current state
# 2 action
# -2.617370474172102 target
# Step 105 @ Episode 1/1 (0.0)[-0.50482733  0.00165546] current state
# 1 action
# -2.6231740872758906 target
# Step 106 @ Episode 1/1 (0.0)[-0.50331259  0.00151475] current state
# 0 action
# -2.626607828917981 target
# Step 107 @ Episode 1/1 (0.0)[-5.02949891e-01  3.62695301e-04] current state
# 2 action
# -2.6647493645934044 target
# Step 108 @ Episode 1/1 (0.0)[-0.50174196  0.00120793] current state
# 1 action
# -2.6698432477146348 target
# Step 109 @ Episode 1/1 (0.0)[-0.50069784  0.00104412] current state
# 0 action
# -2.670717568569148 target
# Step 110 @ Episode 1/1 (0.0)[-5.00825347e-01 -1.27502855e-04] current state
# 2 action
# -2.7122344902715487 target
# Step 111 @ Episode 1/1 (0.0)[-0.50012352  0.00070183] current state
# 1 action
# -2.7162818761408434 target
# Step 112 @ Episode 1/1 (0.0)[-0.49959761  0.00052591] current state
# 0 action
# -2.7142123728836185 target
# Step 113 @ Episode 1/1 (0.0)[-0.50025155 -0.00065394] current state
# 2 action
# -2.7596898475413756 target
# Step 114 @ Episode 1/1 (0.0)[-5.00080454e-01  1.71096036e-04] current state
# 1 action
# -2.7624375318716288 target
# Step 115 @ Episode 1/1 (0.0)[-5.00085599e-01 -5.14506649e-06] current state
# 0 action
# -2.757238247688344 target
# Step 116 @ Episode 1/1 (0.0)[-0.50126695 -0.00118135] current state
# 0 action
# -2.7920502831299348 target
# Step 117 @ Episode 1/1 (0.0)[-0.50361566 -0.00234871] current state
# 1 action
# -2.7935301286133067 target
# Step 118 @ Episode 1/1 (0.0)[-0.50611415 -0.00249849] current state
# 2 action
# -2.8053482633477946 target
# Step 119 @ Episode 1/1 (0.0)[-0.50774372 -0.00162957] current state
# 0 action
# -2.835313901571825 target
# Step 120 @ Episode 1/1 (0.0)[-0.51049216 -0.00274844] current state
# 1 action
# -2.8383871995509518 target
# Step 121 @ Episode 1/1 (0.0)[-0.51333887 -0.00284671] current state
# 2 action
# -2.853165784934911 target
# Step 122 @ Episode 1/1 (0.0)[-0.51526252 -0.00192365] current state
# 0 action
# -2.8797199256461847 target
# Step 123 @ Episode 1/1 (0.0)[-0.51824868 -0.00298616] current state
# 1 action
# -2.884395330708007 target
# Step 124 @ Episode 1/1 (0.0)[-0.52127497 -0.00302629] current state
# 2 action
# -2.9011156585704905 target
# Step 125 @ Episode 1/1 (0.0)[-0.52331869 -0.00204372] current state
# 0 action
# -2.9255916440777487 target
# Step 126 @ Episode 1/1 (0.0)[-0.52636451 -0.00304582] current state
# 1 action
# -2.9316981225670107 target
# Step 127 @ Episode 1/1 (0.0)[-0.52938958 -0.00302507] current state
# 2 action
# -2.949114658685649 target
# Step 128 @ Episode 1/1 (0.0)[-0.53137123 -0.00198165] current state
# 0 action
# -2.97300794332775 target
# Step 129 @ Episode 1/1 (0.0)[-0.53429458 -0.00292336] current state
# 1 action
# -2.9801928399908992 target
# Step 130 @ Episode 1/1 (0.0)[-0.53713774 -0.00284315] current state
# 2 action
# -2.9969115353046627 target
# Step 131 @ Episode 1/1 (0.0)[-0.53887937 -0.00174164] current state
# 0 action
# -3.021776782437065 target
# Step 132 @ Episode 1/1 (0.0)[-0.54150645 -0.00262707] current state
# 1 action
# -3.0295368572927477 target
# Step 133 @ Episode 1/1 (0.0)[-0.54399928 -0.00249283] current state
# 2 action
# -3.0441255295011147 target
# Step 134 @ Episode 1/1 (0.0)[-0.5453392  -0.00133992] current state
# 0 action
# -3.071483268959156 target
# Step 135 @ Episode 1/1 (0.0)[-0.54751619 -0.00217699] current state
# 1 action
# -3.0792241459106413 target
# Step 136 @ Episode 1/1 (0.0)[-0.54951395 -0.00199776] current state
# 2 action
# -3.0903418877672735 target
# Step 137 @ Episode 1/1 (0.0)[-0.55031754 -0.00080359] current state
# 0 action
# -3.1215962262292876 target
# Step 138 @ Episode 1/1 (0.0)[-0.55192095 -0.00160341] current state
# 1 action
# -3.1287067972606333 target
# Step 139 @ Episode 1/1 (0.0)[-0.5533122  -0.00139125] current state
# 2 action
# -3.1352314564887007 target
# Step 140 @ Episode 1/1 (0.0)[-5.53480902e-01 -1.68697707e-04] current state
# 0 action
# -3.171594524400854 target
# Step 141 @ Episode 1/1 (0.0)[-0.55442578 -0.00094488] current state
# 1 action
# -3.177519966140341 target
# Step 142 @ Episode 1/1 (0.0)[-0.55513979 -0.00071401] current state
# 2 action
# -3.178652768030198 target
# Step 143 @ Episode 1/1 (0.0)[-5.54617597e-01  5.22196094e-04] current state
# 0 action
# -3.2210717214048836 target
# Step 144 @ Episode 1/1 (0.0)[-5.54863095e-01 -2.45498363e-04] current state
# 1 action
# -3.22537272697428 target
# Step 145 @ Episode 1/1 (0.0)[-5.54874454e-01 -1.13596122e-05] current state
# 2 action
# -3.2207067641353153 target
# Step 146 @ Episode 1/1 (0.0)[-0.55365159  0.00122286] current state
# 2 action
# -3.253719398157512 target
# Step 147 @ Episode 1/1 (0.0)[-0.55120364  0.00244795] current state
# 1 action
# -3.257090264514917 target
# Step 148 @ Episode 1/1 (0.0)[-0.54854888  0.00265475] current state
# 0 action
# -3.268036228746826 target
# Step 149 @ Episode 1/1 (0.0)[-0.54670718  0.00184171] current state
# 2 action
# -3.2940322516129035 target
# Step 150 @ Episode 1/1 (0.0)[-0.5436923   0.00301488] current state
# 1 action
# -3.3000476225214874 target
# Step 151 @ Episode 1/1 (0.0)[-0.5405268   0.00316549] current state
# 0 action
# -3.315152319665067 target
# Step 152 @ Episode 1/1 (0.0)[-0.53823441  0.0022924 ] current state
# 2 action
# -3.3350417097480696 target
# Step 153 @ Episode 1/1 (0.0)[-0.53483228  0.00340213] current state
# 1 action
# -3.3436301521950615 target
# Step 154 @ Episode 1/1 (0.0)[-0.53134592  0.00348636] current state
# 0 action
# -3.361798045957297 target
# Step 155 @ Episode 1/1 (0.0)[-0.52880146  0.00254446] current state
# 2 action
# -3.3774112036294843 target
# Step 156 @ Episode 1/1 (0.0)[-0.52521798  0.00358348] current state
# 1 action
# -3.3882468258206204 target
# Step 157 @ Episode 1/1 (0.0)[-0.52162235  0.00359562] current state
# 0 action
# -3.40805984270666 target
# Step 158 @ Episode 1/1 (0.0)[-0.51904155  0.0025808 ] current state
# 2 action
# -3.421545657513642 target
# Step 159 @ Episode 1/1 (0.0)[-0.51549493  0.00354662] current state
# 1 action
# -3.434047168603387 target
# Step 160 @ Episode 1/1 (0.0)[-0.51200908  0.00348585] current state
# 0 action
# -3.4538332575089097 target
# Step 161 @ Episode 1/1 (0.0)[-0.50961013  0.00239894] current state
# 2 action
# -3.467502314482874 target
# Step 162 @ Episode 1/1 (0.0)[-0.50631607  0.00329406] current state
# 1 action
# -3.4808706170008645 target
# Step 163 @ Episode 1/1 (0.0)[-0.50315158  0.0031645 ] current state
# 0 action
# -3.498816663395003 target
# Step 164 @ Episode 1/1 (0.0)[-0.50114033  0.00201124] current state
# 2 action
# -3.5149905318304557 target
# Step 165 @ Episode 1/1 (0.0)[-0.4982974   0.00284293] current state
# 1 action
# -3.5282852196413197 target
# Step 166 @ Episode 1/1 (0.0)[-0.49564405  0.00265335] current state
# 0 action
# -3.542588685197869 target
# Step 167 @ Episode 1/1 (0.0)[-0.49420012  0.00144394] current state
# 2 action
# -3.5634670104300903 target
# Step 168 @ Episode 1/1 (0.0)[-0.49197638  0.00222373] current state
# 1 action
# -3.5757095989238628 target
# Step 169 @ Episode 1/1 (0.0)[-0.48998946  0.00198692] current state
# 0 action
# -3.5847488519290347 target
# Step 170 @ Episode 1/1 (0.0)[-0.48925419  0.00073528] current state
# 2 action
# -3.6122952460868354 target
# Step 171 @ Episode 1/1 (0.0)[-0.48777604  0.00147815] current state
# 1 action
# -3.6225788722857417 target
# Step 172 @ Episode 1/1 (0.0)[-0.48656604  0.00120999] current state
# 0 action
# -3.625074556933255 target
# Step 173 @ Episode 1/1 (0.0)[-4.86633222e-01 -6.71797157e-05] current state
# 2 action
# -3.6609163175495203 target
# Step 174 @ Episode 1/1 (0.0)[-0.48597708  0.00065615] current state
# 1 action
# -3.6685029715315736 target
# Step 175 @ Episode 1/1 (0.0)[-4.85602493e-01  3.74582468e-04] current state
# 0 action
# -3.663646002120129 target
# Step 176 @ Episode 1/1 (0.0)[-0.48651227 -0.00090977] current state
# 2 action
# -3.708982925515236 target
# Step 177 @ Episode 1/1 (0.0)[-4.86699614e-01 -1.87348244e-04] current state
# 1 action
# -3.7133771790015784 target
# Step 178 @ Episode 1/1 (0.0)[-4.87163142e-01 -4.63527099e-04] current state
# 0 action
# -3.7009089536188946 target
# Step 179 @ Episode 1/1 (0.0)[-0.48889939 -0.00173625] current state
# 0 action
# -3.7244169814400205 target
# Step 180 @ Episode 1/1 (0.0)[-0.49189542 -0.00299603] current state
# 1 action
# -3.7272614152011156 target
# Step 181 @ Episode 1/1 (0.0)[-0.49512886 -0.00323344] current state
# 2 action
# -3.7495939590057907 target
# Step 182 @ Episode 1/1 (0.0)[-0.49757557 -0.00244671] current state
# 0 action
# -3.7619885315211805 target
# Step 183 @ Episode 1/1 (0.0)[-0.50121725 -0.00364168] current state
# 1 action
# -3.768510204018316 target
# Step 184 @ Episode 1/1 (0.0)[-0.50502667 -0.00380942] current state
# 2 action
# -3.797941485746862 target
# Step 185 @ Episode 1/1 (0.0)[-0.50797531 -0.00294864] current state
# 0 action
# -3.8020902104087733 target
# Step 186 @ Episode 1/1 (0.0)[-0.51204108 -0.00406577] current state
# 1 action
# -3.8124455609521197 target
# Step 187 @ Episode 1/1 (0.0)[-0.51619352 -0.00415244] current state
# 2 action
# -3.84713642943615 target
# Step 188 @ Episode 1/1 (0.0)[-0.51940149 -0.00320797] current state
# 0 action
# -3.8457823757410474 target
# Step 189 @ Episode 1/1 (0.0)[-0.52364094 -0.00423945] current state
# 1 action
# -3.8597077046755173 target
# Step 190 @ Episode 1/1 (0.0)[-0.52788007 -0.00423913] current state
# 2 action
# -3.897254422476598 target
# Step 191 @ Episode 1/1 (0.0)[-0.5310871  -0.00320702] current state
# 0 action
# -3.8934695063666758 target
# Step 192 @ Episode 1/1 (0.0)[-0.53523796 -0.00415087] current state
# 1 action
# -3.910243312791287 target
# Step 193 @ Episode 1/1 (0.0)[-0.53930155 -0.00406359] current state
# 2 action
# -3.9478012766871173 target
# Step 194 @ Episode 1/1 (0.0)[-0.54224742 -0.00294586] current state
# 0 action
# -3.944752698765832 target
# Step 195 @ Episode 1/1 (0.0)[-0.54605349 -0.00380607] current state
# 1 action
# -3.963254933230541 target
# Step 196 @ Episode 1/1 (0.0)[-0.54969128 -0.00363779] current state
# 2 action
# -3.9977667490313213 target
# Step 197 @ Episode 1/1 (0.0)[-0.55213357 -0.00244229] current state
# 0 action
# -3.998537518132334 target
# Step 198 @ Episode 1/1 (0.0)[-0.55536212 -0.00322855] current state
# 1 action
# -4.017401057039178 target
# Step 199 @ Episode 1/1 (0.0)

# %%
plotting.plot_cost_to_go_mountain_car(env, estimator)
plotting.plot_episode_stats(stats, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)
